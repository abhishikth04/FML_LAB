# %% [markdown]
# <a href="https://colab.research.google.com/github/abhishikth04/FML_LAB/blob/main/APPL_MATPLOTLIB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **MATPLOTLIB**
#
# *  it is a Data Visualisation Package in python
# *  Data should be visualised in terms of **"Graphs or charts"** we can use MATPLOTLIB
#
# *  By using **pyplot and pylab** modules we can create different charts or graphs

# %% [markdown]
# # **Line Graph**

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(0,10,2)
y = x**2
print(x,y)
# Out:
# [0 2 4 6 8] [ 0  4 16 36 64]

# %%
plt.plot(x,y)
plt.show()

# %%
plt.plot(x,y,ls = "dotted") # ls means line style
plt.show()

# %%
plt.plot(x,y,ls = "dashed") # ls means line style
plt.show()

# %%
plt.plot(x,y,ls = "dashdot") # ls means line style
plt.show()

# %%
plt.plot(x,y,ls = "none") # ls means line style
plt.show() # none represents no line

# %%
plt.plot(x,y, marker = "." ,ls = "none") # ls means line style
plt.show()

# %%
plt.plot(x,y, marker = "." ) # ls means line style
plt.show()

# %%
plt.plot(x,y, marker = "." , c= "m" ) # c means colour
plt.show()

# %%
plt.plot(x,y, marker = "." , c= "k" ) # c means colour
plt.show()

# %%
plt.plot(x,y, marker = "*" , c= "g" ) # c means colour
plt.show()

# %%
plt.plot(x,y, marker = "." , c= "g" , lw = "10" ) # lw means linewidth
plt.show()

# %%
plt.plot(x,y, marker = "." , c= "b" , lw = "10" , ls = "dotted" ) # lw means linewidth
plt.show()

# %%
x = np.arange(0,10,2)
y1 = x**2
y2 = x**3
y3 = x**4
plt.plot(x,y1)
plt.plot(x,y2)
plt.plot(x,y3)
plt.show() # shows multiple lines in singe graph

# %%
x = np.arange(0,10,2)
y1 = x**2
y2 = x**3
y3 = x**4
#plt.plot(x,y1)
#plt.plot(x,y2)
#plt.plot(x,y3)
plt.plot(x,y1,x,y2,x,y3)
plt.show() # shows multiple lines in singe graph

# %% [markdown]
# # **Scatter Plot**
#
# It is used to represent a pair of numerical data one with x-axis and another with y-axis.each representation will be in dot form

# %%
x = [2,4,6,8,10,12]
y = [50,70,20,80,90,40]
plt.scatter(x,y) #it relates x with y (representation in the form of plot)
plt.show()

# %%
x = [2,4,6,8,10,12]
y = [50,70,20,80,90,50]
c = ["orange","yellow","purple","black","green","maroon"]
plt.scatter(x,y , c= c) #it relates x with y (representation in the form of plot)
plt.show()

# %%
x = [2,4,6,8,10,12]
y = [50,70,20,80,90,45]
#c = ["orange","yellow","purple","black","green","maroon"]
plt.scatter(x,y , color = "maroon" ) #it relates x with y (representation in the form of plot)
plt.show()

# %%
x = [2,4,6,8,10,12]
y = [50,70,20,80,90,40]
#c = ["orange","yellow","purple","black","green","maroon"]
size = [100,200,50,150,300,250]
plt.scatter(x,y , color = "red" , s = size ) #it relates x with y (representation in the form of plot)
plt.show()

# %%
x = [2,4,6,8,10,12]
y = [50,70,20,80,90,40]
#c = ["orange","yellow","purple","black","green","maroon"]
size = [100,200,50,150,300,250]
plt.scatter(x,y , color = "maroon" , s = size , alpha = 0.5) #it relates x with y (representation in the form of plot)
plt.show() # alpha means transparency

# %%
x = [2,4,6,8,10,12]
y = [50,70,20,80,90,40]
#c = ["orange","yellow","purple","black","green","maroon"]
size = [100,200,50,150,300,250]
plt.scatter(x,y , c = c , s = size , alpha = 1 , cmap = "viridis") #it relates x with y (representation in the form of plot)
plt.show() # alpha means transparency
# Out:
# <ipython-input-37-3ca4903b0abb>:5: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(x,y , c = c , s = size , alpha = 1 , cmap = "viridis") #it relates x with y (representation in the form of plot)

# %%
x = [2,4,6,8,10,12]
y = [50,70,20,80,90,40]
#c = ["black","orange","magenta","purple","green","maroon"]
size = [100,200,50,150,300,250]
plt.scatter(x,y , c = c , s = size , alpha = 1 , cmap = "viridis") #it relates x with y (representation in the form of plot)
plt.colorbar()
plt.show() # alpha means transparency
# Out:
# <ipython-input-38-058afaa56fde>:5: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(x,y , c = c , s = size , alpha = 1 , cmap = "viridis") #it relates x with y (representation in the form of plot)

# %%
x = [2,4,6,8,10,12]
y = [50,70,20,80,90,40]
c = ["orange","yellow","purple","black","green","maroon"]
size = [100,200,50,150,300,250]
plt.scatter(x,y , c = c , s = size , alpha = 1 , cmap = "viridis") #it relates x with y (representation in the form of plot)
x = [2,4,6,8,10,12]
y = [25,65,95,75,55,35]
c = ["orange","yellow","purple","black","green","maroon"]
size = [100,200,50,150,300,250]
plt.scatter(x,y , c = c , s = size , alpha = 1 , cmap = "viridis") #it relates x with y (representation in the form of plot)
plt.colorbar()
plt.show() # alpha means transparency
# Out:
# <ipython-input-39-2c92fb2adece>:5: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(x,y , c = c , s = size , alpha = 1 , cmap = "viridis") #it relates x with y (representation in the form of plot)
# <ipython-input-39-2c92fb2adece>:10: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(x,y , c = c , s = size , alpha = 1 , cmap = "viridis") #it relates x with y (representation in the form of plot)

# %%
x = [2,4,6,8,10,12]
y = [50,70,20,80,90,40]
#c = ["orange","yellow","purple","black","green","maroon"]
size = [100,200,50,150,300,250]
plt.scatter(x,y , color = "orange" , s = size , alpha = 1 , cmap = "viridis") #it relates x with y (representation in the form of plot)
x = [2,4,6,8,10,12]
y = [25,65,95,75,55,35]
#c = ["orange","yellow","purple","black","green","maroon"]
size = [100,200,50,150,300,250]
plt.scatter(x,y , color = "purple" , s = size , alpha = 1 , cmap = "viridis") #it relates x with y (representation in the form of plot)
plt.colorbar()
plt.show() # alpha means transparency
# Out:
# <ipython-input-41-4c38885c04df>:5: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(x,y , color = "orange" , s = size , alpha = 1 , cmap = "viridis") #it relates x with y (representation in the form of plot)
# <ipython-input-41-4c38885c04df>:10: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(x,y , color = "purple" , s = size , alpha = 1 , cmap = "viridis") #it relates x with y (representation in the form of plot)

# %% [markdown]
# # **Histogram**
#
# Histogram is accurate representation of the distribution of numerical data
#
# Divide the data into different intervals

# %%
marks = [90,95,20,35,70,75,60,65,30,50]
grade_intervals = [0,50,80,100]
plt.title("Student Grade")
plt.hist(marks,grade_intervals,histtype = "bar" , rwidth = 0.7) # reduce width
plt.xticks([0,50,80,100])
plt.xlabel("percentage")
plt.ylabel("No.of Students")
plt.show()

# %%
marks = [90,95,20,35,70,75,60,65,30,56]
grade_intervals = [0,50,80,100]
plt.title("Student Grade")
plt.hist(marks,grade_intervals,histtype = "step" , rwidth = 0.7) # reduce width
plt.xticks([0,50,80,100])
plt.xlabel("percentage")
plt.ylabel("No.of Students")
plt.show()

# %%
marks = [90,95,20,35,70,75,60,65,30,55]
grade_intervals = [0,50,80,100]
plt.title("Student Grade")
plt.hist(marks,grade_intervals,histtype = "stepfilled" , rwidth = 0.7 , facecolor = "b") # reduce width
plt.xticks([0,50,80,100])
plt.xlabel("percentage")
plt.ylabel("No.of Students")
plt.show()

# %%
marks = [90,95,20,35,70,75,60,65,30,55]
grade_intervals = [0,50,80,100]
plt.title("Student Grade")
plt.hist(marks,grade_intervals,histtype = "bar" , rwidth = 0.7 , facecolor = "g") # reduce width
plt.xticks([0,50,80,100])
plt.xlabel("percentage")
plt.ylabel("No.of Students")
plt.show()

# %% [markdown]
# # **BAR PLOT**
#
# Bar plot or Bar chart is graph usually represnts the category of data with rctangular bars the

# %%
x = ['A','B','H','I']
y = [30,50,70,90]
plt.bar(x,y)
plt.show(x,y)

# %%
x = ['A','B','H','I']
y = [30,50,70,90]
plt.bar(x,y , color = "magenta")
plt.show(x,y)

# %%
x = ['A','B','H','I']
y = [30,50,70,90]
plt.bar(x,y , color = "purple" , width = 0.5)
plt.show(x,y)

# %%
x = ['A','B','H','I']
y = [30,50,70,90]
plt.bar(x,y , color = "turquoise" , width = 0.2) # by default it will take 0.8
plt.show(x,y)

# %%
x = ['A','B','H','I']
y = [30,50,70,90]
plt.barh(x,y , color = "indigo" , height = 0.5) # by default it will take 0.8
plt.show(x,y)

# %%
x = ['A','B','H','I']
y = [30,50,70,90]
c = ["maroon","black","pink","yellow"]
plt.barh(x,y , color = c , height = 0.5) # by default it will take 0.8
plt.show(x,y)

# %%
x = ["2020" , "2021" , "2022" , "2023"] # vertical bar representation
y = [280,350,470,590]
c = ["green","skyblue","pink","yellow"]
plt.bar(x,y,color=c,width=0.3) #by default it will take 0.8
plt.xlabel("Year")
plt.ylabel("no of students passed")
plt.title("Placemnts Data" , color="purple")
plt.show()

# %% [markdown]
# # **BOX PLOT**
#
# > The shape of the boxplot shows how the dta is distributed and it also shows any outliers

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
list1 = [11,4,6,8,6,9,3]
fig = plt.figure(figsize = (10,7))
plt.boxplot(list1)
plt.show()

# %%
# orange line shows medium value
# first quartral and mdium is same

list2 = [1,2,2,2,3,5,6]
fig = plt.figure(figsize = (10,7))
plt.boxplot(list2)
plt.show()

# %%
list1 = [11,4,6,8,6,9,3]
fig = plt.figure(figsize = (5,5))
plt.boxplot(list1 , notch= True)
plt.show()

# %%
list1 = [11,4,6,8,6,9,3]
fig = plt.figure(figsize = (10,7))
plt.boxplot(list1 , vert= False)
plt.show()

# %%
list1 = [11,4,6,8,6,9,3]
fig = plt.figure(figsize = (5,4))
plt.boxplot(list1 , widths = 0.6)
plt.show()

# %%
list1 = [11,4,6,8,6,9,3]
fig = plt.figure(figsize = (5,4))
plt.boxplot(list1 , labels = ["Abhi"] , widths = 0.5)
plt.show()

# %%
list1 = [11,4,6,8,6,9,3]
fig = plt.figure(figsize = (5,4))
plt.boxplot(list1 , labels = ["Abhi"] , widths = 0.3 , patch_artist = True)
plt.show()

# %%
list1 = [11,4,6,8,6,9,3]
fig = plt.figure(figsize = (5,4))
plt.boxplot(list1 , labels = ["Abhi"] , widths = 0.3 , patch_artist = False, showmeans = True)
plt.show()

# %%
list1 = [11,4,6,8,6,9,3]
fig = plt.figure(figsize = (5,4))
plt.boxplot(list1 , labels = ["Abhi"] , widths = 0.3 , patch_artist = False, showmeans = True , boxprops = dict(color="r"))
plt.show()

# %% [markdown]
# # **PIECHART**
#
# > A Pie chart is a circular statistical plot that can display only one series of data. The area of chart is the total percentage of given data

# %%
import matplotlib.pyplot as plt

# %%
Student_performance = ['Excellent' , 'Good' , 'Average' , 'Poor']
Student_values = [35,30,20,15]
plt.pie(Student_values)
plt.show()

# %%
# Division of Given values

# %%
Student_performance = ['Excellent' , 'Good' , 'Average' , 'Poor']
Student_values = [35,30,20,15]
plt.pie(Student_values , labels = Student_performance)
plt.show()

# %%
Student_performance = ['Excellent' , 'Good' , 'Average' , 'Poor']
Student_values = [35,30,20,15]
plt.pie(Student_values , labels = Student_performance , startangle = 90)
# startangle means where it should represents
plt.show()

# %%
Student_performance = ['Excellent' , 'Good' , 'Average' , 'Poor']
Student_values = [35,30,20,15]
plt.pie(Student_values , labels = Student_performance , startangle = 180)
# startangle means where it should represents
# counter plots
plt.show()

# %%
Student_performance = ['Excellent' , 'Good' , 'Average' , 'Poor']
Student_values = [35,30,20,15]
plt.pie(Student_values , labels = Student_performance , startangle = 0 , explode = [0.3,0,0,0])
# startangle means where it should represents
# counter plots
# explode extract takes default value 0 , if you give any value it seperates from the pie chart
plt.show()

# %%
Student_performance = ['Excellent' , 'Good' , 'Average' , 'Poor']
Student_values = [35,30,20,15]
plt.pie(Student_values , labels = Student_performance , startangle = 0 , explode = [0.2,0.2,0.2,0.2])
# startangle means where it should represents
# counter plots
# explode extract takes default value 0 , if you give any value it seperates from the pie chart
plt.show()

# %%
Student_performance = ['Excellent' , 'Good' , 'Average' , 'Poor']
Student_values = [35,30,20,15]
plt.pie(Student_values , labels = Student_performance , startangle = 0 , explode = [0.2,0.2,0.2,0.2],shadow = True)
# startangle means where it should represents
# counter plots
# explode extract takes default value 0 , if you give any value it seperates from the pie chart
plt.show()

# %%
Student_performance = ['Excellent' , 'Good' , 'Average' , 'Poor']
Student_values = [35,30,20,15]
plt.pie(Student_values , labels = Student_performance , startangle = 0 , explode = [0.2,0.2,0.2,0.2] , colors = ["pink" , "yellow" , "purple" , "skyblue"])
# startangle represents where it should start
# counter plots
# explode extract takes default value 0 , if you give any value it seperates from the pie chart
plt.show()

# %%
Student_performance = ['Excellent' , 'Good' , 'Average' , 'Poor']
Student_values = [35,30,20,15]
plt.pie(Student_values , labels = Student_performance , startangle = 0 , explode = [0.2,0.2,0.2,0.2] , colors = ["pink" , "yellow" , "purple" , "skyblue"])
# startangle means where it should represents
# counter plots
# explode extract takes default value 0 , if you give any value it seperates from the pie chart
plt.legend(title = "Student_performance")
plt.show()

# %%
Student_performance = ['Excellent' , 'Good' , 'Average' , 'Poor']
Student_values = [35,30,20,15]
plt.pie(Student_values , labels = Student_performance , startangle = 0 , explode = [0.2,0.2,0.2,0.2] , colors = ["pink" , "yellow" , "purple" , "skyblue"] , autopct = "%2.2f%%")
# startangle means where it should represents
# counter plots
# explode extract takes default value 0 , if you give any value it seperates from the pie chart
plt.show()

# %%
Student_performance = ['Excellent' , 'Good' , 'Average' , 'Poor']
Student_values = [35,30,20,15]
plt.figure(figsize=(9,10))
plt.pie(Student_values , labels = Student_performance , startangle = 0 , explode = [0.2,0.2,0.2,0.2] , colors = ["pink" , "yellow" , "purple" , "skyblue"] , autopct = "%2.2f%%")
# startangle means where it should represents
# counter plots
# explode extract takes default value 0 , if you give any value it seperates from the pie chart
plt.show()
