# %% [markdown]
# <a href="https://colab.research.google.com/github/abhishikth04/FML_LAB/blob/main/APPL_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **AIM**:
#
# Practice on Python Pandas Library
#
# #**What is Pandas?**
#
# o Pandas is a Python library used for working with data sets.
#
# o It has functions for analysing, cleaning, exploring, and manipulating data.
#
# o The name "Pandas" has a reference to both "Panel Data" and "Python Data Analysis"
# and was created by Wes McKinney in 2008.
#
# #**Why Use Pandas?**
#
# o Pandas allows us to analyse big data and make conclusions based on statistical
# theories.
#
# o Pandas can clean messy data sets, and make them readable and relevant.
#
# o Relevant data is very important in data science.
#
# o Data Science: is a branch of computer science where we study how to store, use and
# analyse data for deriving information from it.
#
# #**What Can Pandas Do?**
#
# Pandas gives you answers about the data. Like:
#
#  Is there a correlation between two or more columns?
#
#  What is average value?
#
#  Max value?
#
#  Min value?
#
# o Pandas are also able to delete rows that are not relevant, or contains wrong values,
# like empty or NULL values. This is called cleaning the data.
#
# o The pandas module mainly works with the tabular data.
#
# o Pandas is capable of offering an in-memory 2D table object called Data frame.
#
# o The most widely used pandas data structures are the Series and Data Frame.
#
# o Simply, a Series is similar to a single column of data while a data frame is similar to a
# sheet with rows and columns.
#
# o There are three main data structures in pandas:
#
#  Series – 1D
#
#  Data Frame – 2D
#
#  Panel – 3D
#
# #**Advantages of Pandas Library**
#
# There are many benefits of Python Pandas library, listing them all would probably take
# more time than what it takes to learn the library. Therefore, these are the core advantages of
# using the Pandas library:
#
# #**Data representation**
#
# Pandas provide extremely streamlined forms of data representation. This helps to analyze
# and understand data better. Simpler data representation facilitates better results for data
# science projects.
#
# #**Less writing and more work done**
#
# It is one of the best advantages of Pandas. What would have taken multiple lines in Python
# without any support libraries, can simply be achieved through 1-2 lines with the use of
# Pandas. Thus, using Pandas helps to shorten the procedure of handling data. With the time
# saved, we can focus more on data analysis algorithms.
#
# #**An extensive set of features**
#
# Pandas are really powerful. They provide you with a huge set of important commands and
# features which are used to easily analyze your data. We can use Pandas to perform various
# tasks like filtering your data according to certain conditions, or segmenting and segregating
# the data according to preference, etc.
#
# #**Efficiently handles large data**
#
# Wes McKinney, the creator of Pandas, made the python library to mainly handle large
# datasets efficiently. Pandas help to save a lot of time by importing large amounts of data very
# fast.
#
# #**Makes data flexible and customizable**
#
# Pandas provide a huge feature set to apply on the data you have so that you can customize,
# edit and pivot it according to your own will and desire. This helps to bring the most out of
# your data.
#
# #**Made for Python**
#
# Python programming has become one of the most sought-after programming languages in
# the world, with its extensive amount of features and the sheer amount of productivity it
# provides. Some of these libraries are NumPy, SciPy, MatPlotLib, etc.
#
# #**Installation of Pandas**
#
# Go to command Prompt and change the locaƟon to where the python has installed in your
# desktop/laptop and use the following command to install PANDAS library.
#
# Pip install pandas
#
# Import pandas
#
# To test whether pandas module is properly installed , try the given command.
# Import pandas
#
# To check the version of pandas, use the given command
#
# Print(pandas._version_)
#
# How to Download Datasets
#
# Large datasets are analysis and manipulates.
#
# #**Dataset**
#
# A Pandas Data Frame is a 2-dimensional data structure, like a 2 dimensional array, or a table
# with rows and columns.
#
# Data is informaƟon recorded systemaƟcally and stated within its context.
#
# #**Free Dataset**
#
# https://www.kaggle.com/
#
# Creatng Data Frame
#
#  Load the data from EXCEL file
#
#  read_excel(“file_locaton”)
#
#  Load the data from CSV file
#
#  read_CSV("file_locaton”)
#
#  Create DataFrame using DICTIONARY
#
#  Create DataFrame using LIST of TUPLES

# %%
import pandas as pd

# %%
data={
    "calories":[420,380,390],
    "duration":[50,40,45]
}
#load data into a DataFrame object:
df=pd.DataFrame(data)
print(df)
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %% [markdown]
# Firstly create a dataset or download a dataset from Kaggle Datasets.
#
# **Dataset : Students Marks(Own Dataset)**
#
# **Create a own Dataset in Excel**
#
# **AfTer that upload the dataset in your google drive**
#
# **Open google drive**
#
# **In Left side top corner New is there (Click on New)**
#
# **Create Folder Name (eg: Datasets)**
#
# **Upload your created datasets files in Datasets folder (Students Marks.xlsx, Duplicates.xlsx,
# Missing values.xlsx)**
#
# **Go to google colab**
#
# **Import pandas as pd**
#
# Read any dataset using pandas.
#
#     data_set = pd.read_csv(‘ ’)
#
# Click on files on leŌ side
#
# Click on Mount Drive.
#
# Connect to Google Drive.
#
# Click on Drive.
#
# Click on My Drive.
#
#
# Click on Datasets.
#
# Click on any dataset (Eg: Students Marks.xlsx)
#
# Copy path the Students Marks.xlsx.
#
# Paste the Copy path.
#
#        data_set = pd.read_csv(‘ Copy Path ’)

# %%
import pandas as pd

# %%
Dataset=pd.read_excel("/content/drive/MyDrive/Data_Sets/Student Marks.xlsx")

# %%
Dataset
# Out:
#     Roll No Name of the Student  C Language  Java  Python  Machine Learning  \
# 0       201                Hema          86    86      91                95
# 1       202                Hari          93    93      83                78
# 2       203                 Ram          89    89      95                92
# 3       204               Latha          98    98      96                77
# 4       205                Rani          87    87      87                92
# 5       206              Jyothi          89    89      82                69
# 6       207             Krishna          90    94      85                68
# 7       208                Raju          94    95      88                78
# 8       209              Suresh          95    96      99                91
# 9       214              Bhavya          69    92      93                82
# 10      210             Sandhya          78    87      87                83
# ...

# %% [markdown]
# # **Indexing Slicing**

# %%
Dataset.head()
# Out:
#    Roll No Name of the Student  C Language  Java  Python  Machine Learning  \
# 0      201                Hema          86    86      91                95
# 1      202                Hari          93    93      83                78
# 2      203                 Ram          89    89      95                92
# 3      204               Latha          98    98      96                77
# 4      205                Rani          87    87      87                92
#
#    Data Science  Artificial Intelligence  Unnamed: 8 Unnamed: 9
# 0            86                       69         NaN        NaN
# 1            93                       70         NaN        NaN
# 2            89                       86         NaN        NaN
# 3            98                       90         NaN        NaN
# 4            87                       96         NaN        NaN

# %% [markdown]
# # **head**()
#
#  Head shows only first 5 records in the dataset.
#
#  If we are giving any number in head(2) it shows parƟcular no.of records. In this 2
# records are displayed.

# %%
Dataset.head(2)
# Out:
#    Roll No Name of the Student  C Language  Java  Python  Machine Learning  \
# 0      201                Hema          86    86      91                95
# 1      202                Hari          93    93      83                78
#
#    Data Science  Artificial Intelligence  Unnamed: 8 Unnamed: 9
# 0            86                       69         NaN        NaN
# 1            93                       70         NaN        NaN

# %%
Dataset.head(7)
# Out:
#    Roll No Name of the Student  C Language  Java  Python  Machine Learning  \
# 0      201                Hema          86    86      91                95
# 1      202                Hari          93    93      83                78
# 2      203                 Ram          89    89      95                92
# 3      204               Latha          98    98      96                77
# 4      205                Rani          87    87      87                92
# 5      206              Jyothi          89    89      82                69
# 6      207             Krishna          90    94      85                68
#
#    Data Science  Artificial Intelligence  Unnamed: 8 Unnamed: 9
# 0            86                       69         NaN        NaN
# 1            93                       70         NaN        NaN
# 2            89                       86         NaN        NaN
# 3            98                       90         NaN        NaN
# ...

# %% [markdown]
# # **tail**()
#
#  Tail shows only last 5 records in the dataset.
#
#  If we are giving any number in tail(10) it shows parƟcular no.of records. In this 10
# records are displayed.

# %%
Dataset.tail()
# Out:
#     Roll No Name of the Student  C Language  Java  Python  Machine Learning  \
# 37      236             Jeevana          85    78      99                88
# 38      237              Ganesh          96    92      87                92
# 39      238           Poorinima          92    77      73                77
# 40      239            Manjusha          91    90      92                97
# 41      240            Nikhitha          93    68      91                69
#
#     Data Science  Artificial Intelligence  Unnamed: 8 Unnamed: 9
# 37            59                       77         NaN        NaN
# 38            60                       92         NaN        NaN
# 39            56                       69         NaN        NaN
# 40            70                       68         NaN        NaN
# 41            85                       78         NaN        NaN

# %%
Dataset.tail(10)
# Out:
#     Roll No Name of the Student  C Language  Java  Python  Machine Learning  \
# 32      231              Devika          99    86      88                95
# 33      232                Isha          87    93      99                96
# 34      233              Apsara          73    89      87                87
# 35      234             Ankitha          66    94      85                82
# 36      235            Anuradha          84    95      88                85
# 37      236             Jeevana          85    78      99                88
# 38      237              Ganesh          96    92      87                92
# 39      238           Poorinima          92    77      73                77
# 40      239            Manjusha          91    90      92                97
# 41      240            Nikhitha          93    68      91                69
#
#     Data Science  Artificial Intelligence  Unnamed: 8 Unnamed: 9
# 32            87                       90         NaN        NaN
# ...

# %% [markdown]
# # **describe**()
#
# describe() shows particular dataset count, mean, std, min, max etc.

# %%
Dataset.describe()
# Out:
#           Roll No  C Language       Java     Python  Machine Learning  \
# count   42.000000   42.000000  42.000000  42.000000         42.000000
# mean   220.285714   86.000000  88.309524  88.380952         86.523810
# std     11.637378    9.268357   6.704524   6.072539          8.560368
# min    201.000000   65.000000  68.000000  73.000000         68.000000
# 25%    210.250000   82.250000  86.000000  85.000000         82.000000
# 50%    220.500000   88.500000  88.500000  88.000000         88.000000
# 75%    229.750000   92.750000  93.000000  92.750000         92.750000
# max    240.000000   99.000000  99.000000  99.000000         99.000000
#
#        Data Science  Artificial Intelligence  Unnamed: 8
# count     42.000000                42.000000         0.0
# mean      85.071429                87.619048         NaN
# std       10.979788                 8.243112         NaN
# min       56.000000                68.000000         NaN
# ...

# %% [markdown]
# # **Shape**
#
#  shape indicates how many rows and columns are present in the dataset.
#
#  Dataset[0:10:2] means it shows 0 to 10 records but exclude 10th record and
# difference is 2.

# %%
Dataset.shape
# Out:
# (42, 10)

# %%
Dataset[0:10:2]
# Out:
#    Roll No Name of the Student  C Language  Java  Python  Machine Learning  \
# 0      201                Hema          86    86      91                95
# 2      203                 Ram          89    89      95                92
# 4      205                Rani          87    87      87                92
# 6      207             Krishna          90    94      85                68
# 8      209              Suresh          95    96      99                91
#
#    Data Science  Artificial Intelligence  Unnamed: 8 Unnamed: 9
# 0            86                       69         NaN        NaN
# 2            89                       86         NaN        NaN
# 4            87                       96         NaN        NaN
# 6            94                       93         NaN        NaN
# 8            96                       98         NaN        NaN

# %% [markdown]
#  Displays all Machine Learning values.

# %%
Dataset["Machine Learning"]
# Out:
# 0     95
# 1     78
# 2     92
# 3     77
# 4     92
# 5     69
# 6     68
# 7     78
# 8     91
# 9     82
# 10    83
# 11    95
# 12    96
# 13    87
# 14    82
# 15    85
# 16    88
# 17    99
# 18    68
# 19    87
# 20    89
# 21    73
# 22    92
# 23    91
# 24    93
# 25    86
# 26    93
# 27    89
# 28    98
# 29    87
# 30    89
# 31    94
# 32    95
# 33    96
# 34    87
# 35    82
# 36    85
# 37    88
# 38    92
# 39    77
# 40    97
# 41    69
# Name: Machine Learning, dtype: int64

# %% [markdown]
#  Displays all Python and Data Science values

# %%
Dataset[["Python","Data Science"]]
# Out:
#     Python  Data Science
# 0       91            86
# 1       83            93
# 2       95            89
# 3       96            98
# 4       87            87
# 5       82            89
# 6       85            94
# 7       88            95
# 8       99            96
# 9       93            92
# 10      87            87
# 11      77            82
# 12      82            85
# 13      86            88
# 14      93            92
# 15      89            77
# 16      98            91
# 17      87            83
# 18      85            94
# 19      89            87
# 20      88            87
# 21      94            89
# 22      95            65
# 23      96            74
# 24      87            94
# 25      82            95
# 26      85            96
# 27      88            87
# 28      92            82
# 29      77            85
# 30      82            88
# 31      85            99
# 32      88            87
# 33      99            66
# 34      87            88
# 35      85            77
# ...

# %% [markdown]
#  Displays all Python, Data Science and ArƟficial Intelligence values.

# %%
Dataset[["Python","Data Science","Artificial Intelligence"]]
# Out:
#     Python  Data Science  Artificial Intelligence
# 0       91            86                       69
# 1       83            93                       70
# 2       95            89                       86
# 3       96            98                       90
# 4       87            87                       96
# 5       82            89                       86
# 6       85            94                       93
# 7       88            95                       89
# 8       99            96                       98
# 9       93            92                       96
# 10      87            87                       87
# 11      77            82                       89
# 12      82            85                       94
# 13      86            88                       95
# 14      93            92                       96
# 15      89            77                       87
# 16      98            91                       82
# 17      87            83                       85
# ...

# %% [markdown]
#  Displays all Python, Data Science and ArƟficial Intelligence values. Range from 0 to 10
# with difference 3.

# %%
Dataset[["Python","Data Science","Artificial Intelligence"]][0:10:3]
# Out:
#    Python  Data Science  Artificial Intelligence
# 0      91            86                       69
# 3      96            98                       90
# 6      85            94                       93
# 9      93            92                       96

# %% [markdown]
# # **Iterrows**()
#
# * Iterrows displayed all columns in row order.

# %%
for rec in Dataset.iterrows():
  print(rec)
# Out:
# (0, Roll No                     201
# Name of the Student        Hema
# C Language                   86
# Java                         86
# Python                       91
# Machine Learning             95
# Data Science                 86
# Artificial Intelligence      69
# Unnamed: 8                  NaN
# Unnamed: 9                  NaN
# Name: 0, dtype: object)
# (1, Roll No                     202
# Name of the Student        Hari
# C Language                   93
# Java                         93
# Python                       83
# Machine Learning             78
# Data Science                 93
# Artificial Intelligence      70
# Unnamed: 8                  NaN
# Unnamed: 9                  NaN
# Name: 1, dtype: object)
# (2, Roll No                    203
# Name of the Student        Ram
# C Language                  89
# Java                        89
# Python                      95
# Machine Learning            92
# Data Science                89
# ...

# %% [markdown]
# #**UNDERSTANDING LOC**[](stop index included)
#
# * data_frame.loc[row_number]
#
# * data_frame.loc[row_number,[column_name,...]]
#
# * data_frame.loc[start:stop]
#
# * data_frame.loc[start:stop,"column_name"]
#
# * data_frame.loc[start:stop,["column_1,column_2,..."]]
#
# * data_frane.loc[start:stop,"column_1":"column_n]

# %% [markdown]
# # **loc**()
#
# *  stop index value also included
#
# *  column name must indicated

# %%
Dataset.loc[1]
# Out:
# Roll No                     202
# Name of the Student        Hari
# C Language                   93
# Java                         93
# Python                       83
# Machine Learning             78
# Data Science                 93
# Artificial Intelligence      70
# Unnamed: 8                  NaN
# Unnamed: 9                  NaN
# Name: 1, dtype: object

# %%
Dataset.loc[15]
# Out:
# Roll No                        216
# Name of the Student        Lakshmi
# C Language                      68
# Java                            77
# Python                          89
# Machine Learning                85
# Data Science                    77
# Artificial Intelligence         87
# Unnamed: 8                     NaN
# Unnamed: 9                     NaN
# Name: 15, dtype: object

# %%
Dataset.loc[29]
# Out:
# Roll No                        228
# Name of the Student        Syamala
# C Language                      82
# Java                            92
# Python                          77
# Machine Learning                87
# Data Science                    85
# Artificial Intelligence         98
# Unnamed: 8                     NaN
# Unnamed: 9                     NaN
# Name: 29, dtype: object

# %%
Dataset
# Out:
#     Roll No Name of the Student  C Language  Java  Python  Machine Learning  \
# 0       201                Hema          86    86      91                95
# 1       202                Hari          93    93      83                78
# 2       203                 Ram          89    89      95                92
# 3       204               Latha          98    98      96                77
# 4       205                Rani          87    87      87                92
# 5       206              Jyothi          89    89      82                69
# 6       207             Krishna          90    94      85                68
# 7       208                Raju          94    95      88                78
# 8       209              Suresh          95    96      99                91
# 9       214              Bhavya          69    92      93                82
# 10      210             Sandhya          78    87      87                83
# ...

# %%
Dataset.loc[19,["Data Science"]]
# Out:
# Data Science    87
# Name: 19, dtype: object

# %%
Dataset.loc[10,["Python","Data Science","Artificial Intelligence"]]
# Out:
# Python                     87
# Data Science               87
# Artificial Intelligence    87
# Name: 10, dtype: object

# %%
Dataset.loc[0:10]
# Out:
#     Roll No Name of the Student  C Language  Java  Python  Machine Learning  \
# 0       201                Hema          86    86      91                95
# 1       202                Hari          93    93      83                78
# 2       203                 Ram          89    89      95                92
# 3       204               Latha          98    98      96                77
# 4       205                Rani          87    87      87                92
# 5       206              Jyothi          89    89      82                69
# 6       207             Krishna          90    94      85                68
# 7       208                Raju          94    95      88                78
# 8       209              Suresh          95    96      99                91
# 9       214              Bhavya          69    92      93                82
# 10      210             Sandhya          78    87      87                83
#
# ...

# %%
Dataset.iloc[0:10]
# Out:
#    Roll No Name of the Student  C Language  Java  Python  Machine Learning  \
# 0      201                Hema          86    86      91                95
# 1      202                Hari          93    93      83                78
# 2      203                 Ram          89    89      95                92
# 3      204               Latha          98    98      96                77
# 4      205                Rani          87    87      87                92
# 5      206              Jyothi          89    89      82                69
# 6      207             Krishna          90    94      85                68
# 7      208                Raju          94    95      88                78
# 8      209              Suresh          95    96      99                91
# 9      214              Bhavya          69    92      93                82
#
#    Data Science  Artificial Intelligence  Unnamed: 8 Unnamed: 9
# 0            86                       69         NaN        NaN
# ...

# %%
Dataset.loc[0:15,"C Language"]
# Out:
# 0     86
# 1     93
# 2     89
# 3     98
# 4     87
# 5     89
# 6     90
# 7     94
# 8     95
# 9     69
# 10    78
# 11    92
# 12    77
# 13    92
# 14    69
# 15    68
# Name: C Language, dtype: int64

# %%
Dataset.loc[19:38,"Java"]
# Out:
# 19    85
# 20    87
# 21    88
# 22    99
# 23    87
# 24    85
# 25    88
# 26    99
# 27    87
# 28    73
# 29    92
# 30    91
# 31    93
# 32    86
# 33    93
# 34    89
# 35    94
# 36    95
# 37    78
# 38    92
# Name: Java, dtype: int64

# %%
Dataset.loc[0:5,["Machine Learning","Python"]]
# Out:
#    Machine Learning  Python
# 0                95      91
# 1                78      83
# 2                92      95
# 3                77      96
# 4                92      87
# 5                69      82

# %%
Dataset.head()
# Out:
#    Roll No Name of the Student  C Language  Java  Python  Machine Learning  \
# 0      201                Hema          86    86      91                95
# 1      202                Hari          93    93      83                78
# 2      203                 Ram          89    89      95                92
# 3      204               Latha          98    98      96                77
# 4      205                Rani          87    87      87                92
#
#    Data Science  Artificial Intelligence  Unnamed: 8 Unnamed: 9
# 0            86                       69         NaN        NaN
# 1            93                       70         NaN        NaN
# 2            89                       86         NaN        NaN
# 3            98                       90         NaN        NaN
# 4            87                       96         NaN        NaN

# %% [markdown]
# # **loc**()
#
# *  stop index value not also included
#
# *  column position must indicated(not column name)

# %% [markdown]
# **UNDERSTANDING ILOCZ**[](stop index excluded)
#
# *data_frame.iloc[row_number,column_number]
#
# *data_frame.iloc[row_start:row_stop,col_start:col_stop]
#
# *data_frame.iloc[start:stop,"column_number"]
#
# *data_frame.iloc[[row_1,row_2,....]]
#
# *data_frame.iloc[:,[col_1,col_2....]]
#
# *data_frame.iloc[start:stop,[col_1,col_2,...]]

# %%
Dataset.iloc[0:5]
# Out:
#    Roll No Name of the Student  C Language  Java  Python  Machine Learning  \
# 0      201                Hema          86    86      91                95
# 1      202                Hari          93    93      83                78
# 2      203                 Ram          89    89      95                92
# 3      204               Latha          98    98      96                77
# 4      205                Rani          87    87      87                92
#
#    Data Science  Artificial Intelligence  Unnamed: 8 Unnamed: 9
# 0            86                       69         NaN        NaN
# 1            93                       70         NaN        NaN
# 2            89                       86         NaN        NaN
# 3            98                       90         NaN        NaN
# 4            87                       96         NaN        NaN

# %%
Dataset.iloc[2,0]
# Out:
# 203

# %%
Dataset.iloc[0:5,0:7]
# Out:
#    Roll No Name of the Student  C Language  Java  Python  Machine Learning  \
# 0      201                Hema          86    86      91                95
# 1      202                Hari          93    93      83                78
# 2      203                 Ram          89    89      95                92
# 3      204               Latha          98    98      96                77
# 4      205                Rani          87    87      87                92
#
#    Data Science
# 0            86
# 1            93
# 2            89
# 3            98
# 4            87

# %%
Dataset.iloc[0:5,1]
# Out:
# 0     Hema
# 1     Hari
# 2      Ram
# 3    Latha
# 4     Rani
# Name: Name of the Student, dtype: object

# %%
Dataset.iloc[[4,6,13,23]]
# Out:
#     Roll No Name of the Student  C Language  Java  Python  Machine Learning  \
# 4       205                Rani          87    87      87                92
# 6       207             Krishna          90    94      85                68
# 13      213              Anusri          92    88      86                87
# 23      222                Niha          65    87      96                91
#
#     Data Science  Artificial Intelligence  Unnamed: 8 Unnamed: 9
# 4             87                       96         NaN        NaN
# 6             94                       93         NaN        NaN
# 13            88                       95         NaN        NaN
# 23            74                       88         NaN        NaN

# %%
Dataset.loc[:,["Data Science"]]
# Out:
#     Data Science
# 0             86
# 1             93
# 2             89
# 3             98
# 4             87
# 5             89
# 6             94
# 7             95
# 8             96
# 9             92
# 10            87
# 11            82
# 12            85
# 13            88
# 14            92
# 15            77
# 16            91
# 17            83
# 18            94
# 19            87
# 20            87
# 21            89
# 22            65
# 23            74
# 24            94
# 25            95
# 26            96
# 27            87
# 28            82
# 29            85
# 30            88
# 31            99
# 32            87
# 33            66
# 34            88
# 35            77
# 36            99
# 37            59
# 38            60
# 39            56
# 40            70
# 41            85

# %%
Dataset.iloc[:,[1,2]]
# Out:
#    Name of the Student  C Language
# 0                 Hema          86
# 1                 Hari          93
# 2                  Ram          89
# 3                Latha          98
# 4                 Rani          87
# 5               Jyothi          89
# 6              Krishna          90
# 7                 Raju          94
# 8               Suresh          95
# 9               Bhavya          69
# 10             Sandhya          78
# 11             Sameera          92
# 12            Santhosh          77
# 13              Anusri          92
# 14              Bhavya          69
# 15             Lakshmi          68
# 16              Ravali          78
# 17               Meena          91
# 18             Krishna          90
# 19              Kalyan          83
# 20            Bhargavi          96
# 21              Charan          87
# 22               Arjun          89
# 23                Niha          65
# 24             Neeraja          74
# 25                Devi          94
# ...

# %%
Dataset.iloc[:,[1,3,5]]
# Out:
#    Name of the Student  Java  Machine Learning
# 0                 Hema    86                95
# 1                 Hari    93                78
# 2                  Ram    89                92
# 3                Latha    98                77
# 4                 Rani    87                92
# 5               Jyothi    89                69
# 6              Krishna    94                68
# 7                 Raju    95                78
# 8               Suresh    96                91
# 9               Bhavya    92                82
# 10             Sandhya    87                83
# 11             Sameera    82                95
# 12            Santhosh    85                96
# 13              Anusri    88                87
# 14              Bhavya    92                82
# 15             Lakshmi    77                85
# 16              Ravali    87                88
# 17               Meena    82                99
# 18             Krishna    94                68
# ...

# %%
Dataset.iloc[0:3,[1,2,5]]
# Out:
#   Name of the Student  C Language  Machine Learning
# 0                Hema          86                95
# 1                Hari          93                78
# 2                 Ram          89                92

# %%
Dataset.iloc[0:8,[1,2,5]]
# Out:
#   Name of the Student  C Language  Machine Learning
# 0                Hema          86                95
# 1                Hari          93                78
# 2                 Ram          89                92
# 3               Latha          98                77
# 4                Rani          87                92
# 5              Jyothi          89                69
# 6             Krishna          90                68
# 7                Raju          94                78

# %%
Dataset.iloc[1:20,[1,2,5]]
# Out:
#    Name of the Student  C Language  Machine Learning
# 1                 Hari          93                78
# 2                  Ram          89                92
# 3                Latha          98                77
# 4                 Rani          87                92
# 5               Jyothi          89                69
# 6              Krishna          90                68
# 7                 Raju          94                78
# 8               Suresh          95                91
# 9               Bhavya          69                82
# 10             Sandhya          78                83
# 11             Sameera          92                95
# 12            Santhosh          77                96
# 13              Anusri          92                87
# 14              Bhavya          69                82
# 15             Lakshmi          68                85
# 16              Ravali          78                88
# 17               Meena          91                99
# ...

# %%
Dataset.iloc[[1,2,5],[1,2,5]]
# Out:
#   Name of the Student  C Language  Machine Learning
# 1                Hari          93                78
# 2                 Ram          89                92
# 5              Jyothi          89                69

# %%
Dataset.iloc[[21,29,32],[2,3,7]]
# Out:
#     C Language  Java  Artificial Intelligence
# 21          87    88                       92
# 29          82    92                       98
# 32          99    86                       90

# %% [markdown]
# #**SORTING DATA FRAME**
#
# * Data_frame.sort_values("column_name")
#
# * Data_frame.sort_values("column_name",ascending=False)
#
# * Data_frame.sort_values(["column_1","column_2"])
#
# * Data_frame.sort_values(["column_1","column_2"],ascending=[0,1])
#
#    Mentioned column values will be sorted in ascending order.

# %%
Dataset
# Out:
#     Roll No Name of the Student  C Language  Java  Python  Machine Learning  \
# 0       201                Hema          86    86   54.30                95
# 1       202                Hari          93    93   54.65                78
# 2       203                 Ram          89    89   54.45                92
# 3       204               Latha          98    98   54.90                77
# 4       205                Rani          87    87   54.35                92
# 5       206              Jyothi          89    89   54.45                69
# 6       207             Krishna          90    94   54.70                68
# 7       208                Raju          94    95   54.75                78
# 8       209              Suresh          95    96   54.80                91
# 9       214              Bhavya          69    92   54.60                82
# 10      210             Sandhya          78    87   54.35                83
# ...

# %%
Dataset.sort_values("Python")
# Out:
#     Roll No Name of the Student  C Language  Java  Python  Machine Learning  \
# 41      240            Nikhitha          93    68   53.40                69
# 28      227             Nandini          87    73   53.65                98
# 39      238           Poorinima          92    77   53.85                77
# 15      216             Lakshmi          68    77   53.85                85
# 37      236             Jeevana          85    78   53.90                88
# 17      218               Meena          91    82   54.10                99
# 11      211             Sameera          92    82   54.10                95
# 24      223             Neeraja          74    85   54.25                93
# 19      219              Kalyan          83    85   54.25                87
# 12      212            Santhosh          77    85   54.25                96
# 32      231              Devika          99    86   54.30                95
# ...

# %% [markdown]
# IF ASCENDING ORDER =FALSE MEANS,PARTICULARCOLUMN VALUES WILL BE DISPLAYED IN DESCENDING ORDER.

# %%
Dataset.sort_values("Python",ascending=False)
# Out:
#     Roll No Name of the Student  C Language  Java  Python  Machine Learning  \
# 37      236             Jeevana          85    78      99                88
# 33      232                Isha          87    93      99                96
# 8       209              Suresh          95    96      99                91
# 16      217              Ravali          78    87      98                88
# 3       204               Latha          98    98      96                77
# 23      222                Niha          65    87      96                91
# 2       203                 Ram          89    89      95                92
# 22      221               Arjun          89    99      95                92
# 21      220              Charan          87    88      94                73
# 14      214              Bhavya          69    92      93                82
# 9       214              Bhavya          69    92      93                82
# ...

# %% [markdown]
#  If we giving no.of columns at a time, but it sorted first mentioned column only.

# %%
Dataset.sort_values(["Java","C Language"])
# Out:
#     Roll No Name of the Student  C Language  Java  Python  Machine Learning  \
# 41      240            Nikhitha          93    68      91                69
# 28      227             Nandini          87    73      92                98
# 15      216             Lakshmi          68    77      89                85
# 39      238           Poorinima          92    77      73                77
# 37      236             Jeevana          85    78      99                88
# 17      218               Meena          91    82      87                99
# 11      211             Sameera          92    82      77                95
# 24      223             Neeraja          74    85      87                93
# 12      212            Santhosh          77    85      82                96
# 19      219              Kalyan          83    85      89                87
# 0       201                Hema          86    86      91                95
# ...

# %%
Dataset.sort_values(["Artificial Intelligence","Machine Learning"])
# Out:
#     Roll No Name of the Student  C Language  Java  Python  Machine Learning  \
# 40      239            Manjusha          91    90   54.50                97
# 39      238           Poorinima          92    77   53.85                77
# 0       201                Hema          86    86   54.30                95
# 1       202                Hari          93    93   54.65                78
# 37      236             Jeevana          85    78   53.90                88
# 22      221               Arjun          89    99   54.95                92
# 41      240            Nikhitha          93    68   53.40                69
# 35      234             Ankitha          66    94   54.70                82
# 16      217              Ravali          78    87   54.35                88
# 17      218               Meena          91    82   54.10                99
# 5       206              Jyothi          89    89   54.45                69
# ...

# %% [markdown]
# # **Manipulating Data Frame**
#
# #**Adding column**
#
# *Data_frame['new_col_name']=default_value
#
# *Data_frame['new_col_name']=Expression/condition
#
# #**Removing column**
#
# *Data_frame.drop(columns="column_name"}
#
# *Data_frame.drop(columns="column_name",implace=True)

# %% [markdown]
# * We can manipulate the data either adding or deleƟng column values.

# %%
Dataset
# Out:
#     Roll No Name of the Student  C Language  Java  Python  Machine Learning  \
# 0       201                Hema          86    86      91                95
# 1       202                Hari          93    93      83                78
# 2       203                 Ram          89    89      95                92
# 3       204               Latha          98    98      96                77
# 4       205                Rani          87    87      87                92
# 5       206              Jyothi          89    89      82                69
# 6       207             Krishna          90    94      85                68
# 7       208                Raju          94    95      88                78
# 8       209              Suresh          95    96      99                91
# 9       214              Bhavya          69    92      93                82
# 10      210             Sandhya          78    87      87                83
# ...

# %%
Dataset["Artificial Intelligence"]=0

# %%
Dataset
# Out:
#     Roll No Name of the Student  C Language  Java  Python  Machine Learning  \
# 0       201                Hema          86    86      91                95
# 1       202                Hari          93    93      83                78
# 2       203                 Ram          89    89      95                92
# 3       204               Latha          98    98      96                77
# 4       205                Rani          87    87      87                92
# 5       206              Jyothi          89    89      82                69
# 6       207             Krishna          90    94      85                68
# 7       208                Raju          94    95      88                78
# 8       209              Suresh          95    96      99                91
# 9       214              Bhavya          69    92      93                82
# 10      210             Sandhya          78    87      87                83
# ...

# %%
Dataset["Artificial Intelligence"]=Dataset["C Language"]+Dataset["Python"]+Dataset["Java"]

# %%
Dataset
# Out:
#     Roll No Name of the Student  C Language  Java  Python  Machine Learning  \
# 0       201                Hema          86    86   54.30                95
# 1       202                Hari          93    93   54.65                78
# 2       203                 Ram          89    89   54.45                92
# 3       204               Latha          98    98   54.90                77
# 4       205                Rani          87    87   54.35                92
# 5       206              Jyothi          89    89   54.45                69
# 6       207             Krishna          90    94   54.70                68
# 7       208                Raju          94    95   54.75                78
# 8       209              Suresh          95    96   54.80                91
# 9       214              Bhavya          69    92   54.60                82
# 10      210             Sandhya          78    87   54.35                83
# ...

# %%
Dataset["Artificial Intelligence"]="orange/apple"

# %%
Dataset
# Out:
#     Roll No Name of the Student  C Language  Java  Python  Machine Learning  \
# 0       201                Hema          86    86      91                95
# 1       202                Hari          93    93      83                78
# 2       203                 Ram          89    89      95                92
# 3       204               Latha          98    98      96                77
# 4       205                Rani          87    87      87                92
# 5       206              Jyothi          89    89      82                69
# 6       207             Krishna          90    94      85                68
# 7       208                Raju          94    95      88                78
# 8       209              Suresh          95    96      99                91
# 9       214              Bhavya          69    92      93                82
# 10      210             Sandhya          78    87      87                83
# ...

# %%
Dataset.drop(columns="Artificial Intelligence")
# Out:
#     Roll No Name of the Student  C Language  Java  Python  Machine Learning  \
# 0       201                Hema          86    86      91                95
# 1       202                Hari          93    93      83                78
# 2       203                 Ram          89    89      95                92
# 3       204               Latha          98    98      96                77
# 4       205                Rani          87    87      87                92
# 5       206              Jyothi          89    89      82                69
# 6       207             Krishna          90    94      85                68
# 7       208                Raju          94    95      88                78
# 8       209              Suresh          95    96      99                91
# 9       214              Bhavya          69    92      93                82
# 10      210             Sandhya          78    87      87                83
# ...

# %%
Dataset
# Out:
#     Roll No Name of the Student  C Language  Java  Python  Machine Learning  \
# 0       201                Hema          86    86      91                95
# 1       202                Hari          93    93      83                78
# 2       203                 Ram          89    89      95                92
# 3       204               Latha          98    98      96                77
# 4       205                Rani          87    87      87                92
# 5       206              Jyothi          89    89      82                69
# 6       207             Krishna          90    94      85                68
# 7       208                Raju          94    95      88                78
# 8       209              Suresh          95    96      99                91
# 9       214              Bhavya          69    92      93                82
# 10      210             Sandhya          78    87      87                83
# ...

# %% [markdown]
# *inplace = True, means parƟcular column will be deleted permanently.

# %%
Dataset.drop(columns="Artificial Intelligence",inplace=True)

# %%
Dataset
# Out:
#     Roll No Name of the Student  C Language  Java  Python  Machine Learning  \
# 0       201                Hema          86    86   54.30                95
# 1       202                Hari          93    93   54.65                78
# 2       203                 Ram          89    89   54.45                92
# 3       204               Latha          98    98   54.90                77
# 4       205                Rani          87    87   54.35                92
# 5       206              Jyothi          89    89   54.45                69
# 6       207             Krishna          90    94   54.70                68
# 7       208                Raju          94    95   54.75                78
# 8       209              Suresh          95    96   54.80                91
# 9       214              Bhavya          69    92   54.60                82
# 10      210             Sandhya          78    87   54.35                83
# ...

# %% [markdown]
# #**REMOVING DUPLICATES**
#
# #**Knowing Duplicates**
#
# * Data_frame.duplicated()-Boolean Result
#
# #**Removing Duplicates**
#
# * Data_frame.drop_duplicates()
#
# * Data_frame.drop_duplicates(inplace=True)

# %% [markdown]
# * If duplicates are present in the dataset, output shows true otherwise false.

# %%
Dataset.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14     True
# 15    False
# 16    False
# 17    False
# 18     True
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27     True
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# dtype: bool

# %%
Dataset=pd.read_excel("/content/drive/MyDrive/Data_Sets/Student Marks Duplicate.xlsx")

# %%
Dataset
# Out:
#     Roll No Name of the Student  C Language  Java  Python  Machine Learning  \
# 0       201                Hema          86    86      91                95
# 1       202                Hari          93    93      83                78
# 2       203                 Ram          89    89      95                92
# 3       204               Latha          98    98      96                77
# 4       205                Rani          87    87      87                92
# 5       206              Jyothi          89    89      82                69
# 6       207             Krishna          90    94      85                68
# 7       208                Raju          94    95      88                78
# 8       209              Suresh          95    96      99                91
# 9       214              Bhavya          69    92      93                82
# 10      210             Sandhya          78    87      87                83
# ...

# %%
Dataset.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14     True
# 15    False
# 16    False
# 17    False
# 18     True
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27     True
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# dtype: bool

# %%
Dataset.drop_duplicates()
# Out:
#     Roll No Name of the Student  C Language  Java  Python  Machine Learning  \
# 0       201                Hema          86    86      91                95
# 1       202                Hari          93    93      83                78
# 2       203                 Ram          89    89      95                92
# 3       204               Latha          98    98      96                77
# 4       205                Rani          87    87      87                92
# 5       206              Jyothi          89    89      82                69
# 6       207             Krishna          90    94      85                68
# 7       208                Raju          94    95      88                78
# 8       209              Suresh          95    96      99                91
# 9       214              Bhavya          69    92      93                82
# 10      210             Sandhya          78    87      87                83
# ...

# %%
Dataset.drop_duplicates(inplace=True)

# %%
Dataset
# Out:
#     Roll No Name of the Student  C Language  Java  Python  Machine Learning  \
# 0       201                Hema          86    86   54.30                95
# 1       202                Hari          93    93   54.65                78
# 2       203                 Ram          89    89   54.45                92
# 3       204               Latha          98    98   54.90                77
# 4       205                Rani          87    87   54.35                92
# 5       206              Jyothi          89    89   54.45                69
# 6       207             Krishna          90    94   54.70                68
# 7       208                Raju          94    95   54.75                78
# 8       209              Suresh          95    96   54.80                91
# 9       214              Bhavya          69    92   54.60                82
# 10      210             Sandhya          78    87   54.35                83
# ...

# %% [markdown]
# #**HANDLING MISSING DATA**
#
#   REMOVING MISSING DATA
#
#   * Data_frame.dropna()
#   * Data_frame.dropna(inplace=True)
#
#   FILL WITH DEFAULT VALUES
#
#   * Data_frame.fillna(default_value)

# %% [markdown]
# * Missing values is filled with any value using “fillna”

# %%
Dataset=pd.read_excel("/content/drive/MyDrive/Data_Sets/Student Marks Missing.xlsx")

# %%
Dataset
# Out:
#     Roll No Name of the Student  C Language  Java  Python  Machine Learning  \
# 0       201                Hema          86    86   54.30                95
# 1       202                Hari          93    93   54.65                78
# 2       203                 Ram          89    89   54.45                92
# 3       204               Latha          98    98   54.90                77
# 4       205                Rani          87    87   54.35                92
# 5       206              Jyothi          89    89   54.45                69
# 6       207             Krishna          90    94   54.70                68
# 7       208                Raju          94    95   54.75                78
# 8       209              Suresh          95    96   54.80                91
# 9       214              Bhavya          69    92   54.60                82
# 10      210             Sandhya          78    87   54.35                83
# ...

# %%
Dataset["Python"].fillna(90)
# Out:
# 0     91.0
# 1     83.0
# 2     95.0
# 3     90.0
# 4     87.0
# 5     82.0
# 6     85.0
# 7     88.0
# 8     99.0
# 9     93.0
# 10    87.0
# 11    90.0
# 12    82.0
# 13    86.0
# 14    93.0
# 15    89.0
# 16    98.0
# 17    87.0
# 18    85.0
# 19    90.0
# 20    88.0
# 21    94.0
# 22    95.0
# 23    90.0
# 24    87.0
# 25    82.0
# 26    85.0
# 27    88.0
# 28    92.0
# 29    77.0
# 30    82.0
# 31    85.0
# 32    88.0
# 33    99.0
# 34    87.0
# 35    85.0
# 36    88.0
# 37    99.0
# 38    87.0
# 39    73.0
# 40    92.0
# 41    91.0
# Name: Python, dtype: float64

# %%
Dataset.fillna(90)
# Out:
#     Roll No Name of the Student  C Language  Java  Python  Machine Learning  \
# 0       201                Hema        86.0  86.0    91.0              95.0
# 1       202                Hari        93.0  93.0    83.0              78.0
# 2       203                 Ram        90.0  89.0    95.0              92.0
# 3       204               Latha        98.0  98.0    90.0              77.0
# 4       205                Rani        87.0  87.0    87.0              92.0
# 5       206              Jyothi        89.0  89.0    82.0              69.0
# 6       207             Krishna        90.0  94.0    85.0              68.0
# 7       208                Raju        94.0  90.0    88.0              90.0
# 8       209              Suresh        95.0  96.0    99.0              91.0
# 9       214              Bhavya        90.0  92.0    93.0              82.0
# 10      210             Sandhya        78.0  87.0    87.0              83.0
# ...

# %%
Dataset.dropna()
# Out:
#     Roll No Name of the Student  C Language  Java  Python  Machine Learning  \
# 0       201                Hema        86.0  86.0    91.0              95.0
# 1       202                Hari        93.0  93.0    83.0              78.0
# 4       205                Rani        87.0  87.0    87.0              92.0
# 5       206              Jyothi        89.0  89.0    82.0              69.0
# 6       207             Krishna        90.0  94.0    85.0              68.0
# 8       209              Suresh        95.0  96.0    99.0              91.0
# 12      212            Santhosh        77.0  85.0    82.0              96.0
# 18      207             Krishna        90.0  94.0    85.0              68.0
# 20      226            Bhargavi        96.0  87.0    88.0              89.0
# 21      220              Charan        87.0  88.0    94.0              73.0
# 25      224                Devi        94.0  88.0    82.0              86.0
# ...

# %%
Dataset
# Out:
#     Roll No Name of the Student  C Language  Java  Python  Machine Learning  \
# 0       201                Hema        86.0  86.0    91.0              95.0
# 1       202                Hari        93.0  93.0    83.0              78.0
# 2       203                 Ram         NaN  89.0    95.0              92.0
# 3       204               Latha        98.0  98.0     NaN              77.0
# 4       205                Rani        87.0  87.0    87.0              92.0
# 5       206              Jyothi        89.0  89.0    82.0              69.0
# 6       207             Krishna        90.0  94.0    85.0              68.0
# 7       208                Raju        94.0   NaN    88.0               NaN
# 8       209              Suresh        95.0  96.0    99.0              91.0
# 9       214              Bhavya         NaN  92.0    93.0              82.0
# 10      210             Sandhya        78.0  87.0    87.0              83.0
# ...

# %% [markdown]
# #**Data Filtering And Conditonal Changes**
#
# * Data_frame.loc[simple_condition]
#
# * Data_frame.loc[compound_condition]
#
# * Data_frame.loc[simple_condition.str.contains(str)]
#
# * Data_frame.loc[simple_condition.str.startswith(str)]
#
# * Data_frame.loc[simple_condition.str.endswith(str)]

# %% [markdown]
# #**SIMPLE CONDITION**
#
# **Data_frame["col_name"]>/</==value**

# %%
import pandas as pd

# %%
Dataset=pd.read_excel("/content/drive/MyDrive/Data_Sets/Student Marks.xlsx")

# %%
Dataset
# Out:
#     Roll No Name of the Student  C Language  Java  Python  Machine Learning  \
# 0       201                Hema          86    86      91                95
# 1       202                Hari          93    93      83                78
# 2       203                 Ram          89    89      95                92
# 3       204               Latha          98    98      96                77
# 4       205                Rani          87    87      87                92
# 5       206              Jyothi          89    89      82                69
# 6       207             Krishna          90    94      85                68
# 7       208                Raju          94    95      88                78
# 8       209              Suresh          95    96      99                91
# 9       214              Bhavya          69    92      93                82
# 10      210             Sandhya          78    87      87                83
# ...

# %%
Dataset.loc[Dataset["Python"]>90]
# Out:
#     Roll No Name of the Student  C Language  Java  Python  Machine Learning  \
# 0       201                Hema          86    86      91                95
# 2       203                 Ram          89    89      95                92
# 3       204               Latha          98    98      96                77
# 8       209              Suresh          95    96      99                91
# 9       214              Bhavya          69    92      93                82
# 14      214              Bhavya          69    92      93                82
# 16      217              Ravali          78    87      98                88
# 21      220              Charan          87    88      94                73
# 22      221               Arjun          89    99      95                92
# 23      222                Niha          65    87      96                91
# 28      227             Nandini          87    73      92                98
# ...

# %%
Dataset.loc[Dataset["Java"]<80]
# Out:
#     Roll No Name of the Student  C Language  Java  Python  Machine Learning  \
# 15      216             Lakshmi          68    77      89                85
# 28      227             Nandini          87    73      92                98
# 37      236             Jeevana          85    78      99                88
# 39      238           Poorinima          92    77      73                77
# 41      240            Nikhitha          93    68      91                69
#
#     Data Science  Artificial Intelligence  Unnamed: 8 Unnamed: 9
# 15            77                       87         NaN        NaN
# 28            82                       89         NaN        NaN
# 37            59                       77         NaN        NaN
# 39            56                       69         NaN        NaN
# 41            85                       78         NaN        NaN

# %%
Dataset.loc[(Dataset["C Language"]>90)&(Dataset["Python"]<85)]
# Out:
#     Roll No Name of the Student  C Language  Java  Python  Machine Learning  \
# 1       202                Hari          93    93      83                78
# 11      211             Sameera          92    82      77                95
# 25      224                Devi          94    88      82                86
# 39      238           Poorinima          92    77      73                77
#
#     Data Science  Artificial Intelligence  Unnamed: 8 Unnamed: 9
# 1             93                       70         NaN        NaN
# 11            82                       89         NaN        NaN
# 25            95                       87         NaN        NaN
# 39            56                       69         NaN        NaN

# %%
Dataset.loc[Dataset["Name of the Student"].str.contains("n")]
# Out:
#     Roll No Name of the Student  C Language  Java  Python  Machine Learning  \
# 4       205                Rani          87    87      87                92
# 6       207             Krishna          90    94      85                68
# 10      210             Sandhya          78    87      87                83
# 12      212            Santhosh          77    85      82                96
# 13      213              Anusri          92    88      86                87
# 17      218               Meena          91    82      87                99
# 18      207             Krishna          90    94      85                68
# 19      219              Kalyan          83    85      89                87
# 21      220              Charan          87    88      94                73
# 22      221               Arjun          89    99      95                92
# 26      225               Bindu          95    99      85                93
# ...

# %%
Dataset.loc[Dataset["Name of the Student"].str.startswith("H")]
# Out:
#    Roll No Name of the Student  C Language  Java  Python  Machine Learning  \
# 0      201                Hema          86    86      91                95
# 1      202                Hari          93    93      83                78
#
#    Data Science  Artificial Intelligence  Unnamed: 8 Unnamed: 9
# 0            86                       69         NaN        NaN
# 1            93                       70         NaN        NaN

# %%
Dataset.loc[Dataset["Name of the Student"].str.startswith("R")]
# Out:
#     Roll No Name of the Student  C Language  Java  Python  Machine Learning  \
# 2       203                 Ram          89    89      95                92
# 4       205                Rani          87    87      87                92
# 7       208                Raju          94    95      88                78
# 16      217              Ravali          78    87      98                88
#
#     Data Science  Artificial Intelligence  Unnamed: 8 Unnamed: 9
# 2             89                       86         NaN        NaN
# 4             87                       96         NaN        NaN
# 7             95                       89         NaN        NaN
# 16            91                       82         NaN        NaN

# %%
Dataset
# Out:
#     Roll No Name of the Student  C Language  Java  Python  Machine Learning  \
# 0       201                Hema          86    86      91                95
# 1       202                Hari          93    93      83                78
# 2       203                 Ram          89    89      95                92
# 3       204               Latha          98    98      96                77
# 4       205                Rani          87    87      87                92
# 5       206              Jyothi          89    89      82                69
# 6       207             Krishna          90    94      85                68
# 7       208                Raju          94    95      88                78
# 8       209              Suresh          95    96      99                91
# 9       214              Bhavya          69    92      93                82
# 10      210             Sandhya          78    87      87                83
# ...

# %%
Dataset["Python"]=(Dataset["Java"]/20)+50

# %%
Dataset
# Out:
#     Roll No Name of the Student  C Language  Java  Python  Machine Learning  \
# 0       201                Hema          86    86   54.30                95
# 1       202                Hari          93    93   54.65                78
# 2       203                 Ram          89    89   54.45                92
# 3       204               Latha          98    98   54.90                77
# 4       205                Rani          87    87   54.35                92
# 5       206              Jyothi          89    89   54.45                69
# 6       207             Krishna          90    94   54.70                68
# 7       208                Raju          94    95   54.75                78
# 8       209              Suresh          95    96   54.80                91
# 9       214              Bhavya          69    92   54.60                82
# 10      210             Sandhya          78    87   54.35                83
# ...

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# Data wrangling is the process of processing data to prepare it for use in the next step.
#
# This processes include merging, grouping, and concatenation.
#
# This kind of manipulation is often needed in data science to get your data in to a form that works well with whatever analysis or algorithms that you're going to put it through.

# %% [markdown]
# Data wrangling is the process of processing data to prepare it for use in the next step.
#
# This processes include merging, grouping, and concatenation.
#
# This kind of manipulation is often needed in data science to get your data in to a form that works well with whatever analysis or algorithms that you're going to put it through.

# %%
import pandas as pd

# %%
d1 = {
    'subject_id': ['1', '2', '3', '4', '5'],
    'student_name': ['John', 'Emily', 'Kate', 'Joseph', 'Dennis']
}

d2 = {
    'subject_id': ['4', '5', '6', '7', '8'],
    'student_name': ['Brian', 'William', 'Lilian', 'Grace', 'Caleb']
}

df1 = pd.DataFrame(d1, columns=['subject_id', 'student_name'])
df2 = pd.DataFrame(d2, columns=['subject_id', 'student_name'])

# %%
df1
# Out:
#   subject_id student_name
# 0          1         John
# 1          2        Emily
# 2          3         Kate
# 3          4       Joseph
# 4          5       Dennis

# %%
df2
# Out:
#   subject_id student_name
# 0          4        Brian
# 1          5      William
# 2          6       Lilian
# 3          7        Grace
# 4          8        Caleb

# %%
pd.merge(df1,df2 ,on='subject_id')
# Out:
#   subject_id student_name_x student_name_y
# 0          4         Joseph          Brian
# 1          5         Dennis        William

# %%
raw = {
    'Name': ['John', 'John', 'Grace', 'Grace', 'Benjamin', 'Benjamin', 'Benjamin',
        'Benjamin', 'John', 'Alex', 'Alex', 'Alex'],
    'Position': [2, 1, 1, 4, 2, 4, 3, 1, 3, 2, 4, 3],
    'Year': [2009, 2010, 2009, 2010, 2010, 2010, 2011, 2012, 2011, 2013, 2013, 2012],
    'Marks':[408, 398, 422, 376, 401, 380, 396, 388, 356, 402, 368, 378]
}
df3 = pd.DataFrame(raw)

# %%
df3
# Out:
#         Name  Position  Year  Marks
# 0       John         2  2009    408
# 1       John         1  2010    398
# 2      Grace         1  2009    422
# 3      Grace         4  2010    376
# 4   Benjamin         2  2010    401
# 5   Benjamin         4  2010    380
# 6   Benjamin         3  2011    396
# 7   Benjamin         1  2012    388
# 8       John         3  2011    356
# 9       Alex         2  2013    402
# 10      Alex         4  2013    368
# 11      Alex         3  2012    378

# %%
group = df3.groupby('Year')

# %%
group

# %%
group.get_group(2010)
# Out:
#        Name  Position  Year  Marks
# 1      John         1  2010    398
# 3     Grace         4  2010    376
# 4  Benjamin         2  2010    401
# 5  Benjamin         4  2010    380

# %%
print(pd.concat([df1, df2]))
# Out:
#   subject_id student_name
# 0          1         John
# 1          2        Emily
# 2          3         Kate
# 3          4       Joseph
# 4          5       Dennis
# 0          4        Brian
# 1          5      William
# 2          6       Lilian
# 3          7        Grace
# 4          8        Caleb

# %%
print(pd.concat([df1, df2],axis=1))
# Out:
#   subject_id student_name subject_id student_name
# 0          1         John          4        Brian
# 1          2        Emily          5      William
# 2          3         Kate          6       Lilian
# 3          4       Joseph          7        Grace
# 4          5       Dennis          8        Caleb

# %% [markdown]
# ## Descriptive Statistics

# %% [markdown]
# describe() function gives the descriptive statistics for numerical columns, but the character columns are excluded.
# The describe() method returns description of the data in the DataFrame.
#
# If the DataFrame contains numerical data, the description contains these information for each column:
#
# count - The number of not-empty values.\
# mean - The average (mean) value.\
# std - The standard deviation.\
# min - the minimum value\
# 25% - The 25% percentile*.\
# 50% - The 50% percentile*.\
# 75% - The 75% percentile*.\
# max - the maximum value.
#
# *Percentile meaning: how many of the values are less than the given percentile.

# %%
data = {
    'Name': ['John', 'Alice', 'Joseph', 'Alex'],
    'English': [64, 78, 68, 58],
    'Maths': [76, 54, 72, 64]
}

df = pd.DataFrame(data)
df.describe()
# Out:
#          English      Maths
# count   4.000000   4.000000
# mean   67.000000  66.500000
# std     8.406347   9.712535
# min    58.000000  54.000000
# 25%    62.500000  61.500000
# 50%    66.000000  68.000000
# 75%    70.500000  73.000000
# max    78.000000  76.000000
